# %% [markdown]
# # Homework 1
#
# **Due Date**: 9/8/24 by 8pm on Canvas
#
# In this homework assignment, you are going to write a task organizer program.
#
# We will say that the task organizer follows this general pattern: `{priority_level: [(task, due_date)]}`
#
# There are three priority levels:
#
# - high
# - medium
# - low
#
# This task organizer requires the use of multiple Python data structures (list, dictionary, tuple). The outer structure is a dictionary. We will use the priority level as the key. For the value, we will use a list of tuples. Within each tuple, the first element is a description of the task, while the second value is the due date to complete that task.
#
# Our task organizer has three different features: **add**, **remove**, and **display**. You are welcome to work on these features in whichever order you wish.
#
# You can work on this by yourself or with one other person in the class. If you are working as a group, only one person needs to submit the assignment on Canvas, but make sure to write who you worked with as a submission comment!

# %% [markdown]
# ## Imports
#
# Let's start by importing the `datetime` package for our program. If you're unfamiliar with this package, you can read up on [the documentation](https://docs.python.org/3/library/datetime.html) for a full overview. We only need a basic part for our program, namely the `date` class. To create a `date` variable, we just need three pieces of information: **year, month, day**.
#
# For example, to create a `date` variable, you could write:
#
# ```Python
# # this represents August 27th, 2024
# my_own_date = date(2024, 8, 27)
# ```

# %%
from datetime import date

# %% [markdown]
# ## Adding Tasks
#
# First, we need a function that is able to add tasks to the organizer. The user will need to provide three key pieces of information:
#
# - the description of the task
# - the priority level for this task
# - the due date for the task (year, month, day)
#
# You need to write validation logic to ensure the program is getting good data from the user. Specifically, you need to ensure:
#
# - the task description can't be empty
# - the priority level has to be either high, medium, or low
# - the due date has to be a valid (e.g., day must exist in given month, cannot be in the past)
#
# A few hints:
#
# - You can use `date.today()` to create an object that represents the current date on your machine
# - If you construct an invalid `date` (like February 31st, 2024), an exception is raised by Python
# - You can use a `try/except` block to check for raised errors (see this quick [explanation](https://www.w3schools.com/python/python_try_except.asp))
# - You can use relational operators (such as `>`, `<`, and `==`) to compare `date` objects

# %%
def add_task(organizer):
    # TODO: write your solution here
    pass # <-- remove me 😼

# %% [markdown]
# ## Removing Tasks
#
# Next, we need a function for the user to be able to remove tasks from the organizer. The user simply needs to enter the task description to remove it. You will need to find this task in the organizer and remove it. There are a couple of edge cases to consider here, like if the organizer is empty, for example.

# %%
def remove_task(organizer):
    # TODO: write your solution here
    pass # <-- remove me 😼

# %% [markdown]
# ## Display Organizer
#
# The user needs a way to visualize their task organizer. Let's write a function that is able to do that.
#
# First, you need to check if the organizer is empty or not. If it is empty, just print a message to let them know. If it is not empty, the function needs to print the various tasks. You need to print these by their priority levels, in order: high, medium, low. Be careful, as there's no guarantee that these priority levels have tasks at all! You need to validate for these different scenarios.
#
# **FYI**: to convert a `date` object to a proper string, you can use the `strftime` method like this:
#
# ```Python
# my_own_date = date(2024, 8, 27)
# print(my_own_date.strftime('%A, %B %d, %Y'))
# ```

# %%
def display(organizer):
    # TODO: write your solution here
    pass # <-- remove me 😼

# %% [markdown]
# ## User Interface
#
# Bringing it all together, we need code to allow the user to interact with their task organizer.

# %%
def add_task(organizer):
    from datetime import date
    import datetime

    task = input("What is the task? ")
    while len(task) == 0:
        print("Error. Task description can not be emtpy")
        task = input("What is the task? ")
    
    print("Adding task:")
    print("What is the priority?")
    print("1. Low")
    print("2. Medium")
    print("3. High")
    priority = input("Please enter a priority from 1 for low, 2 for medium, 3 for high: ")
    
    while int(priority) not in range(1, 4):
        priority = input("Please enter a priority from 1 for low, 2 for medium, 3 for high: ")

    print("When is this task due?")
    year = int(input("Enter year as YYYY: "))
    month = int(input("Enter month as MM: "))
    day = int(input("Enter day as DD: "))

    today = datetime.datetime.now()
    try:
        due_date = date(year, month, day)
    except:
        print("invalid date. Re-enter")
        year = int(input("Enter year as YYYY: "))
        month = int(input("Enter month as MM: "))
        day = int(input("Enter day as DD: "))

    while year < today.year:
        year = int(input("Enter year as YYYY: "))
    while year <= today.year and month < today.month:
        month = int(input("Enter month as MM: "))
    while year <= today.year and month <= today.month and day <= today.day:
        day = int(input("Enter day as DD: "))
    
    due_date = date(year, month, day)
    my_task_tuple = (task, (due_date))
        
    if priority == "1":
        low_priority_tasks.append(my_task_tuple)
        organizer[priority] = (low_priority_tasks)
    elif priority == "2":
        medium_priority_tasks.append(my_task_tuple)
        organizer[priority] = (medium_priority_tasks)
    elif priority == "3":   
        high_priority_tasks.append(my_task_tuple)
        organizer[priority] = (high_priority_tasks)



def remove_task(organizer):

    print("Removing task:")
    print("Enter the description of the task to be removed: ")
    description = input("")
    print(organizer)
    
    
    for key, value in organizer.items():
        print(value)
        for item in value:
            if item[0] == description:
                print(item)
                value.remove(item)
                print(organizer)
            else:
                print("else")


def display(organizer):

    print("Task Organizer Tasks:")
    if (len(high_priority_tasks) != 0):
        print("High Priority:", high_priority_tasks)
    if (len(medium_priority_tasks) != 0):
        print("Medium Priority:", medium_priority_tasks)
    if (len(low_priority_tasks) != 0):
        print("Low Priority:", low_priority_tasks)
    

organizer = {}
low_priority_tasks = []
medium_priority_tasks = []
high_priority_tasks = []
flag = True

while flag:
    
    print('''\
Here are your options:
    (1) Add task to organizer
    (2) Remove task from organizer
    (3) Display the organizer
    (4) Exit the program
    ''')

    user_choice = 0
    while user_choice not in range(1, 5):
        user_choice = int(input('Enter your choice: '))

    if user_choice == 1:
        add_task(organizer)
    elif user_choice == 2:
        remove_task(organizer)
    elif user_choice == 3:
        display(organizer)

    flag = user_choice != 4

    print()
